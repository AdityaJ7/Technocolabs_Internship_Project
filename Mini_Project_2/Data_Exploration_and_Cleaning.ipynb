# %% [markdown]
# ### Libraries and matlplotlib settings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
 
mpl.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_excel('data/default_of_credit_card_clients.xls')
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.shape
# We observe the presence of 30,000 rows and 25 columns
# Out:
# (30000, 25)

# %%
df.info() # Indicates absence of null values in our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
df.select_dtypes(include = ['object']) # Object type features in the dataset
# Out:
#                   ID PAY_1
# 0      798fc410-45c1     2
# 1      8a8c8f3b-8eb4    -1
# 2      85698822-43f5     0
# 3      0737c11b-be42     0
# 4      3b7f77cc-dbc0    -1
# ...              ...   ...
# 29995  ecff42d0-bdc6     0
# 29996  99d1fa0e-222b    -1
# 29997  95cdd3e7-4f24     4
# 29998  00d03f02-04cd     1
# 29999  15d69f9f-5ad3     0
#
# [30000 rows x 2 columns]

# %%
df.select_dtypes(include = ['number']) # Number type features in the dataset
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          20000    2          2         1   24      2     -1     -1     -2
# 1         120000    2          2         2   26      2      0      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57      0     -1      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1      0
# 29997      30000    1          2         2   37      3      2     -1      0
# 29998      80000    1          3         1   41     -1      0      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
np.random.seed(seed=24)

# %%
# Hundred random numbers between 1 and 5
random_integers = np.random.randint(low=1,high=5,size=100)
random_integers
# Out:
# array([3, 4, 1, 4, 2, 2, 2, 1, 4, 4, 1, 4, 4, 3, 4, 4, 4, 4, 4, 4, 2, 3,
#        4, 4, 2, 4, 2, 4, 1, 1, 3, 1, 4, 2, 2, 1, 4, 3, 2, 2, 3, 3, 2, 3,
#        4, 2, 3, 4, 1, 3, 4, 2, 2, 4, 1, 2, 3, 3, 2, 1, 2, 4, 2, 1, 4, 3,
#        1, 2, 1, 3, 4, 2, 3, 4, 1, 3, 2, 1, 1, 3, 3, 4, 3, 2, 4, 1, 4, 4,
#        4, 4, 1, 4, 3, 2, 4, 4, 3, 3, 2, 4])

# %%
# Checking how many of them are equal to 3
is_equal_to_3 = random_integers == 3
is_equal_to_3
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False,  True, False, False,  True,  True, False,  True, False,
#        False,  True, False, False,  True, False, False, False, False,
#        False, False,  True,  True, False, False, False, False, False,
#        False, False,  True, False, False, False,  True, False, False,
#         True, False, False,  True, False, False, False,  True,  True,
#        False,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False,  True,  True, False,
#        False])

# %%
is_equal_to_3[:5]
# Out:
# array([ True, False, False, False, False])

# %%
sum(is_equal_to_3)
# Out:
# 22

# %%
random_integers[is_equal_to_3]
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %% [markdown]
# ## Data Integrity Verification

# %%
# Columns in our dataset
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Analysing our id column to make sure the values are unique
df['ID']
# Out:
# 0        798fc410-45c1
# 1        8a8c8f3b-8eb4
# 2        85698822-43f5
# 3        0737c11b-be42
# 4        3b7f77cc-dbc0
#              ...
# 29995    ecff42d0-bdc6
# 29996    99d1fa0e-222b
# 29997    95cdd3e7-4f24
# 29998    00d03f02-04cd
# 29999    15d69f9f-5ad3
# Name: ID, Length: 30000, dtype: object

# %%
id_counts = df['ID'].value_counts()
id_counts
# Out:
# 6353fd55-d66e    2
# 3cfed539-ad58    2
# dda76366-a407    2
# a9870d3e-b4d1    2
# f5e3478e-cf68    2
#                 ..
# 925bfc9c-ae0f    1
# aec2fbdd-3ae1    1
# 0c74d72b-0db8    1
# bb7a65d1-b759    1
# a924cf2e-07a8    1
# Name: ID, Length: 29687, dtype: int64

# %% [markdown]
# ## Boolean Masking and Data Integrity Verification

# %%
# Mask for catching duplicates
dupe_mask = id_counts == 2
dupe_mask
# Out:
# 6353fd55-d66e     True
# 3cfed539-ad58     True
# dda76366-a407     True
# a9870d3e-b4d1     True
# f5e3478e-cf68     True
#                  ...
# 925bfc9c-ae0f    False
# aec2fbdd-3ae1    False
# 0c74d72b-0db8    False
# bb7a65d1-b759    False
# a924cf2e-07a8    False
# Name: ID, Length: 29687, dtype: bool

# %%
dupe_mask[:5]
# Out:
# 6353fd55-d66e    True
# 3cfed539-ad58    True
# dda76366-a407    True
# a9870d3e-b4d1    True
# f5e3478e-cf68    True
# Name: ID, dtype: bool

# %%
# Number of duplicates
dupe_mask.sum()
# Out:
# 313

# %%
dupe_ids = id_counts.index[dupe_mask]
dupe_ids = list(dupe_ids)

# %%
df.loc[df['ID'].isin(dupe_ids[0:3]),:].head(10)
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 10294  3cfed539-ad58     180000    2          3         2   29    -2     -2
# 10394  3cfed539-ad58          0    0          0         0    0     0      0
# 27572  dda76366-a407     500000    1          1         1   54     0      0
# 27672  dda76366-a407          0    0          0         0    0     0      0
# 28499  6353fd55-d66e     260000    2          2         2   34    -2     -2
# 28599  6353fd55-d66e          0    0          0         0    0     0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 10294     -2     -2  ...          0          0          0         0         0
# 10394      0      0  ...          0          0          0         0         0
# 27572      0      0  ...     489978     493062     474301     18725     18000
# 27672      0      0  ...          0          0          0         0         0
# ...

# %%
#Mask for rows with all O's except in the ID column
df_zero_mask = df == 0

# %%
feature_zero_mask = df_zero_mask.iloc[:,1:].all(axis=1)
sum(feature_zero_mask)
# Out:
# 315

# %%
df_clean_1 = df.loc[~feature_zero_mask,:].copy()

# %%
df_clean_1 # Cleaned dataframe where we removed the rows with 0 in all the columns neglecting the id column
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24     2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2      85698822-43f5      90000    2          2         2   34     0      0
# 3      0737c11b-be42      50000    2          2         1   37     0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57    -1      0
# ...              ...        ...  ...        ...       ...  ...   ...    ...
# 29995  ecff42d0-bdc6     220000    1          3         1   39     0      0
# 29996  99d1fa0e-222b     150000    1          3         2   43    -1     -1
# 29997  95cdd3e7-4f24      30000    1          2         2   37     4      3
# 29998  00d03f02-04cd      80000    1          3         1   41     1     -1
# 29999  15d69f9f-5ad3      50000    1          2         1   46     0      0
#
# ...

# %%
df_clean_1['ID'].nunique()
# Out:
# 29685

# %%
valid_pay_1_mask = df_clean_1['PAY_1'] != 'Not available'
valid_pay_1_mask[0:5]
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: PAY_1, dtype: bool

# %%
df_clean_2 = df_clean_1.loc[valid_pay_1_mask,:].copy()
df_clean_2 # data frame where the pay_1 value is not equal to 'Not available'
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24     2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2      85698822-43f5      90000    2          2         2   34     0      0
# 3      0737c11b-be42      50000    2          2         1   37     0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57    -1      0
# ...              ...        ...  ...        ...       ...  ...   ...    ...
# 29995  ecff42d0-bdc6     220000    1          3         1   39     0      0
# 29996  99d1fa0e-222b     150000    1          3         2   43    -1     -1
# 29997  95cdd3e7-4f24      30000    1          2         2   37     4      3
# 29998  00d03f02-04cd      80000    1          3         1   41     1     -1
# 29999  15d69f9f-5ad3      50000    1          2         1   46     0      0
#
# ...

# %%
df_clean_2['PAY_1'] = df_clean_2['PAY_1'].astype('int64')
df_clean_2[['PAY_1', 'PAY_2']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26664 entries, 0 to 29999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PAY_1   26664 non-null  int64
#  1   PAY_2   26664 non-null  int64
# dtypes: int64(2)
# memory usage: 624.9 KB

# %%
df_clean_2['EDUCATION'].replace(to_replace=[0, 5, 6], value=4, inplace=True)
df_clean_2['EDUCATION'].value_counts()
# Out:
# 2    12458
# 1     9412
# 3     4380
# 4      414
# Name: EDUCATION, dtype: int64

# %%
df_clean_2['EDUCATION'].hist()
plt.show()

# %%
df_clean_2['MARRIAGE'].replace(to_replace=0, value=3, inplace=True)
df_clean_2['MARRIAGE'].value_counts()
# Out:
# 2    14158
# 1    12172
# 3      334
# Name: MARRIAGE, dtype: int64

# %%
df_clean_2['MARRIAGE'].hist()
plt.show()

# %%
df_clean_2['EDUCATION_CAT'] = 'none'

# %%
df_clean_2[['EDUCATION', 'EDUCATION_CAT']].head(10)
# Out:
#    EDUCATION EDUCATION_CAT
# 0          2          none
# 1          2          none
# 2          2          none
# 3          2          none
# 4          2          none
# 5          1          none
# 6          1          none
# 7          2          none
# 8          3          none
# 9          3          none

# %%
cat_mapping = {
    1: "graduate school",
    2: "university",
    3: "high school",
    4: "others"
}

# %%
df_clean_2['EDUCATION_CAT'] = df_clean_2['EDUCATION'].map(cat_mapping)
df_clean_2[['EDUCATION', 'EDUCATION_CAT']].head(10)
# Out:
#    EDUCATION    EDUCATION_CAT
# 0          2       university
# 1          2       university
# 2          2       university
# 3          2       university
# 4          2       university
# 5          1  graduate school
# 6          1  graduate school
# 7          2       university
# 8          3      high school
# 9          3      high school

# %% [markdown]
# ## Exploring the Credit Limit and Demographic Features

# %%
df_clean_2[['LIMIT_BAL', 'AGE']].hist()
plt.show()

# %%
df_clean_2[['LIMIT_BAL', 'AGE']].describe()
# Out:
#            LIMIT_BAL           AGE
# count   26664.000000  26664.000000
# mean   167919.054905     35.505213
# std    129839.453081      9.227442
# min     10000.000000     21.000000
# 25%     50000.000000     28.000000
# 50%    140000.000000     34.000000
# 75%    240000.000000     41.000000
# max    800000.000000     79.000000

# %%
df_clean_2.groupby('EDUCATION').agg({'default payment next month':'mean'}).plot.bar(legend=False)
plt.ylabel('Default rate')
plt.xlabel('Education level: ordinal encoding')
plt.show()

# %% [markdown]
# ## Exploring Financial History

# %%
pay_feats = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# %%
df_clean_2[pay_feats].describe()
# Out:
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# std        1.126769      1.198640      1.199165      1.167897      1.131735
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  26664.000000
# mean      -0.293579
# std        1.150229
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
df_clean_2[pay_feats[0]].value_counts().sort_index()
# Out:
# -2     2476
# -1     5047
#  0    13087
#  1     3261
#  2     2378
#  3      292
#  4       63
#  5       23
#  6       11
#  7        9
#  8       17
# Name: PAY_1, dtype: int64

# %%
df_clean_2[pay_feats[0]].hist()

# %%
pay_1_bins = np.array(range(-2,10)) - 0.5
pay_1_bins
# Out:
# array([-2.5, -1.5, -0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,
#         8.5])

# %%
df_clean_2[pay_feats[0]].hist(bins=pay_1_bins)
plt.xlabel('PAY_1')
plt.ylabel('Number of accounts')
plt.show()

# %%
mpl.rcParams['font.size'] = 5
df_clean_2[pay_feats].hist(bins=pay_1_bins, layout=(2,3))
plt.show()

# %%
df.loc[df['PAY_2']==2, ['PAY_2', 'PAY_3']].head()
# Out:
#     PAY_2  PAY_3
# 0       2     -1
# 1       2      0
# 13      2      2
# 15      2      0
# 50      2      2

# %%
edu_ohe = pd.get_dummies(df_clean_2['EDUCATION_CAT'])
edu_ohe.head(10)
df_with_ohe = pd.concat([df_clean_2, edu_ohe], axis=1)
df_with_ohe[['EDUCATION_CAT', 'graduate school',
             'high school', 'university', 'others']].head(10)
df_with_ohe.to_csv('cleaned_data.csv', index=False)
